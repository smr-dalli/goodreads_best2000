# %%
import pandas as pd
import numpy as np

# %%
df_new= pd.read_csv("Best_00s.csv")

# %%
df_new.head()
# Out:
#    Unnamed: 0                                          Title_URL  \
# 0           0  https://www.goodreads.com/book/show/136251.Har...
# 1           1  https://www.goodreads.com/book/show/2767052-th...
# 2           2  https://www.goodreads.com/book/show/1.Harry_Po...
# 3           3  https://www.goodreads.com/book/show/6.Harry_Po...
# 4           4  https://www.goodreads.com/book/show/2.Harry_Po...
#
#                                                Title           Author  \
# 0  Harry Potter and the Deathly Hallows (Harry Po...     J.K. Rowling
# 1            The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# 2  Harry Potter and the Half-Blood Prince (Harry ...     J.K. Rowling
# 3  Harry Potter and the Goblet of Fire (Harry Pot...     J.K. Rowling
# 4  Harry Potter and the Order of the Phoenix (Har...     J.K. Rowling
#
#    num_reviews  num_pages                                             awards  \
# ...
